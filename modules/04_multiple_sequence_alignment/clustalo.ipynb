# %%
# %%bash
# # DMPs from Arabidopsis thaliana, Oryza sativa, and Zea mays (Date Accessed: September 22-26, 2024)
#
# # AtDMPs from (https://www.arabidopsis.org/).
# AtDMPs_v1_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Arabidopsis_thaliana/v1_keyword_searched/AtDMPs_nuc_seq_merged_v1.fasta
# AtDMPs_v2_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Arabidopsis_thaliana/v2_based_from_paper/AtDMPs_nuc_seq_merged_v2.fasta
#
# # OsDMPs from the query DMP sequences use in the paper of <paper SWEETPOTATO>, and sequences lifted from annotated sequences obtained from (https://rice.uga.edu/).
# OsDMPs_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Oryza_sativa/OsDMPs_nuc_seq_merged.fasta
#
# # ZmDMPs from a simple keyword search of "DMP" in this website, (https://www.maizegdb.org/gene_center/gene).
# ZmDMPs_v1_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Zea_mays/v1/ZmDMPs_nuc_seq_merged_v1.fasta
# ZmDMPs_v2_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Zea_mays/v2/ZmDMPs_nuc_seq_merged_v2.fasta

# %%
# %%bash
# AtDMPs_v1_fasta_FILE=/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Arabidopsis_thaliana/v1_keyword_searched/AtDMPs_nuc_seq_merged_v1.fasta
# AtDMPs_v1_fasta_files_FILE="/mnt/e/_ELBI/_MASTER/MBB_300_Master_Thesis/_DMP_Eggplant/01_Identification/query_fasta_file/Arabidopsis_thaliana/v1_keyword_searched/AtDMP_fasta_files/*.fasta"
#
# clustalo -i $AtDMPs_v1_fasta_FILE -o 02_MSA/AtDMPs_v1_clustalo.fa -v --force

# %%
# %%bash
# clustalo --help
# Out:
# Clustal Omega - 1.2.4 (AndreaGiacomo)
#
# If you like Clustal-Omega please cite:
#  Sievers F, Wilm A, Dineen D, Gibson TJ, Karplus K, Li W, Lopez R, McWilliam H, Remmert M, Söding J, Thompson JD, Higgins DG.
#  Fast, scalable generation of high-quality protein multiple sequence alignments using Clustal Omega.
#  Mol Syst Biol. 2011 Oct 11;7:539. doi: 10.1038/msb.2011.75. PMID: 21988835.
# If you don't like Clustal-Omega, please let us know why (and cite us anyway).
#
# Check http://www.clustal.org for more information and updates.
#
# ...
